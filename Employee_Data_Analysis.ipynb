# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# read and print dataset
df = pd.read_csv('/content/drive/MyDrive/DATASET/employeedata.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#TO show the index, list of columns, datatypes of each columns, memory usage of the dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
#provides descriptive statistics of a DataFrame, including measures of central tendency, dispersion, and shape of the distribution of a dataset.
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['Number'].plot(kind='hist', bins=20, title='Number')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
## print first five rows
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
## print last five rows
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
#check and count null values
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
# fill null values with a common value
df.fillna(value={'Salary':0,'College':'Unknown'})
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# check and count duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# print column names
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
# print column datatypes
df.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
#  change the data of that Height column with any random numbers between 150 and 180.

# %%
df['Height']=np.random.randint(150,181,size=len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     173     235
# 2     John Holland  Boston Celtics      30       SG   27     151     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     170     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     154     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     155     203
# 454      Raul Neto       Utah Jazz      25       PG   24     163     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     171     256
# 456    Jeff Withey       Utah Jazz      24        C   26     172     231
# 457       Priyanka       Utah Jazz      34        C   25     169     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# 1. How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
total_employees = len(df)
df1 = df["Team"].value_counts()
print((df1/total_employees*100).round(2))
# Out:
# New Orleans Pelicans      4.15
# Memphis Grizzlies         3.93
# Utah Jazz                 3.49
# New York Knicks           3.49
# Milwaukee Bucks           3.49
# Brooklyn Nets             3.28
# Portland Trail Blazers    3.28
# Oklahoma City Thunder     3.28
# Denver Nuggets            3.28
# Washington Wizards        3.28
# Miami Heat                3.28
# Charlotte Hornets         3.28
# Atlanta Hawks             3.28
# San Antonio Spurs         3.28
# Houston Rockets           3.28
# Boston Celtics            3.28
# Indiana Pacers            3.28
# Detroit Pistons           3.28
# Cleveland Cavaliers       3.28
# Chicago Bulls             3.28
# Sacramento Kings          3.28
# Phoenix Suns              3.28
# Los Angeles Lakers        3.28
# Los Angeles Clippers      3.28
# Golden State Warriors     3.28
# Toronto Raptors           3.28
# Philadelphia 76ers        3.28
# Dallas Mavericks          3.28
# Orlando Magic             3.06
# Minnesota Timberwolves    3.06
# ...

# %%
df1
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
total_employees
# Out:
# 458

# %% [markdown]
# 2. Segregate the employees w.r.t different positions.

# %%
df2 = df.groupby('Position').size()
print(df2.to_string())
# Out:
# Position
# C      79
# PF    100
# PG     92
# SF     85
# SG    102

# %%
df2 = df.groupby(['Position', 'Name']).size()
print(df2.to_string())
# Out:
# Position  Name
# C         Al Horford                  1
#           Al Jefferson                1
#           Alan Williams               1
#           Alex Len                    1
#           Alexis Ajinca               1
#           Andre Drummond              1
#           Andrew Bogut                1
#           Aron Baynes                 1
#           Bismack Biyombo             1
#           Boban Marjanovic            1
#           Boris Diaw                  1
#           Brook Lopez                 1
#           Chris Kaman                 1
#           Cody Zeller                 1
#           Cole Aldrich                1
#           DeAndre Jordan              1
#           DeMarcus Cousins            1
#           Dewayne Dedmon              1
#           Dwight Howard               1
#           Ed Davis                    1
#           Enes Kanter                 1
#           Festus Ezeli                1
#           Frank Kaminsky III          1
# ...

# %% [markdown]
# 3. Find from which age group most of the employees belong to.

# %%
# Create the histogram plot to analyse frequency distribution for employee age
plt.hist(df['Age'])

# add features
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram Plot')

# Display the plot
plt.show()

# %% [markdown]
# 4. Find out under which team and position, spending in terms of salary is high.

# %%
df3 = df.groupby(['Team', 'Position'])['Salary'].sum().sort_values(ascending=False)
print(df3.head(1))
# Out:
# Team                Position
# Los Angeles Lakers  SF          31866445.0
# Name: Salary, dtype: float64

# %% [markdown]
# 5. Find if there is any correlation between age and salary , represent it visually.

# %%
df4 = df[['Age', 'Salary']]
df5 = df4.corr()
df5
# Out:
#              Age    Salary
# Age     1.000000  0.214009
# Salary  0.214009  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot
sns.scatterplot(x='Age', y='Salary', data=df)

# Add labels and title
plt.title('Correlation between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')

# Display the plot
plt.show()

# %%
# Load dataset
df4 = df[['Age', 'Salary']]

# Compute correlation matrix
corr = df4.corr()

# Create heatmap
sns.heatmap(corr, annot=True, cmap="flare", center=0, linewidth=1)

# Add title
plt.title("Correlation between Age and Salary")

# Show plot
plt.show()
